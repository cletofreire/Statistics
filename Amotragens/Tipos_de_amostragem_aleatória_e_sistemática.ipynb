# %% [markdown]
# <br>

# %% [markdown]
# #### Vamos utilizar a função sample do Python para calcular amostras aleatórias de uma lista, que consideraremos como nossa população

# %%
from random import sample

# %%
populacao = ['Gato','Cachorro','Rato','Galinha','Macaco', 'Arara','Vaca','Cavalo','Porco', 'Guiné','Ganso', 'Zebra']

# %% [markdown]
# Amostra aleatória simples de tamanho 4

# %%
sample(populacao, 4)
# Out:
# ['Porco', 'Zebra', 'Vaca', 'Galinha']

# %%
sample(populacao, 4)
# Out:
# ['Cavalo', 'Ganso', 'Guiné', 'Arara']

# %%
sample(populacao, 4)
# Out:
# ['Gato', 'Cachorro', 'Zebra', 'Arara']

# %%
sample(populacao, 4)
# Out:
# ['Zebra', 'Guiné', 'Cavalo', 'Macaco']

# %% [markdown]
# #### Importando a biblioteca pandas (https://pandas.pydata.org)

# %%
import pandas

# %%
df = pandas.DataFrame(populacao, columns = ["Animals"])
df
# Out:
#      Animals
# 0       Gato
# 1   Cachorro
# 2       Rato
# 3    Galinha
# 4     Macaco
# 5      Arara
# 6       Vaca
# 7     Cavalo
# 8      Porco
# 9      Guiné
# 10     Ganso
# 11     Zebra

# %% [markdown]
# Amostra aleatória simples de tamanho 4

# %%
df.sample(n = 4)
# Out:
#    Animals
# 4   Macaco
# 9    Guiné
# 11   Zebra
# 0     Gato

# %%
df.sample(n = 4)
# Out:
#     Animals
# 8     Porco
# 1  Cachorro
# 4    Macaco
# 0      Gato

# %%
df.sample(n = 4)
# Out:
#     Animals
# 3   Galinha
# 0      Gato
# 11    Zebra
# 9     Guiné

# %% [markdown]
# Ao invés de passar o tamanho da amostra que queremos para o Pandas, podemos passar a proporção do todo que queremos na nossa amostra.

# %%
df.sample(frac = 0.33)
# Out:
#     Animals
# 4    Macaco
# 10    Ganso
# 3   Galinha
# 5     Arara

# %%
df.sample(frac = 0.33)
# Out:
#    Animals
# 3  Galinha
# 0     Gato
# 7   Cavalo
# 6     Vaca

# %%
df.sample(frac = 0.33)
# Out:
#    Animals
# 0     Gato
# 2     Rato
# 9    Guiné
# 3  Galinha

# %%
# Amostragem Sistemática

# %% [markdown]
# <br>

# %% [markdown]
# #### Vamos usar o exemplo acima, onde pegamos a terceira ocorrência, começando da segunda observação.

# %%
import numpy as np

# %% [markdown]
# #### Usando python puro, ficaria assim:

# %%
tamanho_populacao = len(populacao)

# %%
for i in range(1, tamanho_populacao, 3):
    print(i)
# Out:
# 1
# 4
# 7
# 10

# %%
amostra_sistematica_exemplo = []
for amostras in range(1, tamanho_populacao, 3):
    amostra_sistematica_exemplo.append(populacao[amostras])

# %%
amostra_sistematica_exemplo
# Out:
# [2, 5, 8, 11]

# %% [markdown]
# #### Exatamente como no exemplo!!

# %% [markdown]
# #### Para calcularmos uma amostra sistemática no Pandas, a lógica é a mesma. Vamos utilizar os índices do pandas para filtrar somente as posições que queremos

# %%
np.arange(1, 12, step=3)
# Out:
# array([ 1,  4,  7, 10])

# %%
def amostragem_sistematica(df, inicio = 0, step = 3):
    indexes = np.arange(inicio, df.shape[0], step=step)
    amostra = df.iloc[indexes]
    return amostra

# %%
amostragem_sistematica(df, 0, 3)
# Out:
#    Animals
# 0     Gato
# 3  Galinha
# 6     Vaca
# 9    Guiné

# %% [markdown]
# #### Exatamente como no exemplo!!
